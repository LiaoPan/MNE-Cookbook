# %%
import mne
import numpy as np
import matplotlib.pyplot as plt

# %%
spike = np.load('check_spike.npy')
print(spike.shape)
# Out:
# (200, 39, 300)

# %%
plt.plot(spike[11,...].T);

# %%
non_spike = np.load('non_check.npy')
plt.plot(non_spike[142,...].T);

# %%
spike_f = np.load('meg_spike_sets.npy')
plt.plot(spike_f[94,...].T);

# %%
non_spike = np.load('meg_non_spike_sets.npy')
plt.plot(non_spike[94,...].T);
